# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive
# Out:
# Mounted at /gdrive
# /gdrive

# %%
# %cd ..

# %ls
# Out:
# /gdrive/MyDrive/Horror Excel/Progetto Covid Gruppo Horror
#  1_Data_exploration.py
# '8.Ospedalizzati vs pazienti in terapia intensiva per regione.png'
# 'Analisi Federica'/
# 'Analisi Marco'/
# 'Analisi Margot '/
# 'Analisi Martina'/
#  casi_per_rip_geo.png
# 'Colori Esagonali.png'
#  comuni_clean.csv
# 'covid19_province _python.csv'
# 'covid19_region _python.csv'
#  covid19_region_python_w_daily_deaths.csv
#  covid19_reg_ripartite.csv
#  Creazione_Colonna_Daily_Deaths.py
# 'Distribuzione degli Ospedalizzati totali e in Terapia Intensiva per Regione.py'
#  fiumi_clean.csv
#  Grafico_Italia_Mappa_Incidenza_Decessi_OK.py
#  ITA_adm1_modified.cpg
#  ITA_adm1_modified.dbf
#  ITA_adm1_modified.shp
#  ITA_adm1_modified.shx
#  Regioni_clean_venerdì_2.csv
#  Report_Analisi_Covid_Gruppo_Horror.docx
# 'Ripartizione-geografica _python.txt'
# 'TRACCIA PRESENTAZIONE - Built Week 2.pdf'

# %%
#import del csv preso in esame
df_province = pd.read_csv("covid19_province _python.csv", sep=";")

# %%
# Casi Totali dal 6 dicembre 2020
data_6_dicembre = df_province[df_province['Date'].str.startswith('2020-12-06')]

# Ordinamento dei dati in base ai casi totali positivi
province_ordinate = data_6_dicembre.sort_values(by='TotalPositiveCases', ascending=False)

# Sorted per Nome e Casi
province_ordinate = province_ordinate[['ProvinceName', 'TotalPositiveCases']]

province_ordinate.head(25)  #TOP 25
# Out:
#                 ProvinceName  TotalPositiveCases
# 40109                 Milano              158717
# 40071                 Napoli              102702
# 40095                   Roma               96985
# 40137                 Torino               94349
# 40106                 Varese               45944
# 40117  Monza e della Brianza               44603
# 40111                Brescia               36010
# 40195                Treviso               31952
# 40102                 Genova               31864
# 40197                 Padova               31073
# 40192                 Verona               31020
# 40069                Caserta               30616
# 40176                Firenze               30331
# 40107                   Como               29942
# 40193                Vicenza               29365
# 40080                Bologna               29063
# 40110                Bergamo               25914
# 40131                Bolzano               25361
# ...
