# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive
# Out:
# Mounted at /gdrive
# /gdrive

# %%
# %cd 'Progetto Covid Gruppo Horror'/
# %ls

# %%
#importazione file
df_regioni = pd.read_csv("covid19_region_python_w_daily_deaths.csv", sep=",")

# %%
#conversione della data
df_regioni["Date"] = pd.to_datetime (df_regioni["Date"], dayfirst= True)

# %%
#set dell'indice
df_regioni.set_index("Date", inplace=True)

# %%
#grandezza della figura
plt.figure(figsize=(12,6))

#utilizzo il resample per ottenere il raggruppamento per mese --definito con "M"
df_regioni.resample("M")["Recovered"].sum().plot(kind = "line")
df_regioni.resample("M")["CurrentPositiveCases"].sum().plot(kind = "line")
#legenda e titolo
plt.legend(["Guariti","Casi Positivi"], loc = "best")
plt.title("Andamento Temporale dei Casi positivi e guariti")
# Out:
# Text(0.5, 1.0, 'Andamento Temporale dei Casi positivi e guariti')
