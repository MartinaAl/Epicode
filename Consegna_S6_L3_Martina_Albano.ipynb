# %% [markdown]
# Andiamo a questo link e scarichiamo una serie di dataset: https://www.kaggle.com/datasets/ahmettezcantekin/beginner-datasets Tra i vari dataset presenti, ce n'è uno che contiene diverse qualità di vini e le misure di diverse proprietà organolettiche: wine.csv; Effettuiamo calcoliamo le informazioni statistiche base (numerosità, modie, mode, mediane, quartili, ecc) sulle colonne numeriche usando python

# %%
import pandas as pd

# %%
#importazione file
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).
# /gdrive

# %%
# %cd 'S6 L3 - Esempi pratici di utilizzo di NumPy con Python'/
# %ls
# Out:
# /gdrive/MyDrive/Epicode/UNIT 2: gennaio 16 - febbraio 1/S6 L3 - Esempi pratici di utilizzo di NumPy con Python
# 'Consegna S6 L3'   iris/  'Teoria S6 L3.ipynb'   wine.csv

# %%
file_name="/wine.csv"

# %%
TabIris=pd.read_csv("wine.csv")

# %%
TabIris
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 6492            6.2              0.21         0.29             1.6      0.039
# 6493            6.6              0.32         0.36             8.0      0.047
# 6494            6.5              0.24         0.19             1.2      0.041
# 6495            5.5              0.29         0.30             1.1      0.022
# 6496            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
#media
TabIris.mean()
# Out:
# <ipython-input-82-49221f39ed69>:2: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   TabIris.mean()
# fixed acidity             7.215307
# volatile acidity          0.339666
# citric acid               0.318633
# residual sugar            5.443235
# chlorides                 0.056034
# free sulfur dioxide      30.525319
# total sulfur dioxide    115.744574
# density                   0.994697
# pH                        3.218501
# sulphates                 0.531268
# alcohol                  10.491801
# quality                   5.818378
# dtype: float64

# %%
#moda
TabIris.mode()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            6.8              0.28          0.3             2.0      0.044
# 1            NaN               NaN          NaN             NaN        NaN
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 29.0                 111.0   0.9972  3.16        0.5
# 1                  NaN                   NaN   0.9976   NaN        NaN
#
#    alcohol  quality   type
# 0      9.5      6.0  white
# 1      NaN      NaN    NaN

# %%
#primo quartile
TabIris.quantile(0.25)
# Out:
# <ipython-input-84-6ed75fd1cb82>:2: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   TabIris.quantile(0.25)
# fixed acidity            6.40000
# volatile acidity         0.23000
# citric acid              0.25000
# residual sugar           1.80000
# chlorides                0.03800
# free sulfur dioxide     17.00000
# total sulfur dioxide    77.00000
# density                  0.99234
# pH                       3.11000
# sulphates                0.43000
# alcohol                  9.50000
# quality                  5.00000
# Name: 0.25, dtype: float64

# %%
#secondo quartile (mediana)
TabIris.median()
# Out:
# <ipython-input-85-721538c3f666>:2: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   TabIris.median()
# fixed acidity             7.00000
# volatile acidity          0.29000
# citric acid               0.31000
# residual sugar            3.00000
# chlorides                 0.04700
# free sulfur dioxide      29.00000
# total sulfur dioxide    118.00000
# density                   0.99489
# pH                        3.21000
# sulphates                 0.51000
# alcohol                  10.30000
# quality                   6.00000
# dtype: float64

# %%
#terzo quartile
TabIris.quantile(0.75)
# Out:
# <ipython-input-86-dc2f05999e0a>:2: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   TabIris.quantile(0.75)
# fixed acidity             7.70000
# volatile acidity          0.40000
# citric acid               0.39000
# residual sugar            8.10000
# chlorides                 0.06500
# free sulfur dioxide      41.00000
# total sulfur dioxide    156.00000
# density                   0.99699
# pH                        3.32000
# sulphates                 0.60000
# alcohol                  11.30000
# quality                   6.00000
# Name: 0.75, dtype: float64

# %% [markdown]
# Esercizio 1/2 Scarichiamo l'Iris dataset da qui: https://archive.ics.uci.edu/dataset/53/iris Troveremo un file .data, che è un CSV, e un file .names con i metadati; questa versione del dataset non ha i nomi di colonna. • Leggiamo il file e carichiamolo in un DataFrame mediante pd.read_csv() senza utilizzare altri parametri • Stampiamo le prime cinque righe • Stampiamo i nomi di colonna: descrivono cosa c'è nella colonna relativa?

# %%
#importazione iris
# %ls
# Out:
# bezdekIris.data  Index  iris.data  iris.names

# %%
#importazione iris
TabIris2 = pd.read_csv("iris.data", names=["sepal.length", "sepal.width", "petal.length", "petal.width", "class"])
TabIris2.head(5)
# Out:
#    sepal.length  sepal.width  petal.length  petal.width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %% [markdown]
# Dal dataset di prima: • Leggiamo il file e carichiamolo in un DataFrame, aggiungendo i nomi di colonna — che si trovano nel file .names — come parametro di pd.read_csv() • Stampiamo le prime cinque righe e le ultime dieci • Stampiamo un riepilogo dei descrittori statistici del dataset

# %%
DataIris=pd.DataFrame=(TabIris2)
DataIris.head(5)
# Out:
#    sepal.length  sepal.width  petal.length  petal.width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
DataIris.tail(10)
# Out:
#      sepal.length  sepal.width  petal.length  petal.width           class
# 140           6.7          3.1           5.6          2.4  Iris-virginica
# 141           6.9          3.1           5.1          2.3  Iris-virginica
# 142           5.8          2.7           5.1          1.9  Iris-virginica
# 143           6.8          3.2           5.9          2.3  Iris-virginica
# 144           6.7          3.3           5.7          2.5  Iris-virginica
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
